# %%
import mne
import os

data_path = r"C:\Users\hiro2\Documents\EEG_project\data\MUSIN-G"

set_path = os.path.join(data_path, "sub-001", "ses-01", "eeg",
                        "sub-001_ses-01_task-MusicListening_run-1_eeg.set")

print("ファイル存在確認:", os.path.exists(set_path))

raw = mne.io.read_raw_eeglab(set_path, preload=True, verbose=False)

print("\n=== データ基本情報 ===")
print(f"チャンネル数: {len(raw.ch_names)}")
print(f"サンプリング周波数: {raw.info['sfreq']} Hz")
print(f"記録時間: {raw.times[-1]:.1f} 秒")
print(f"\nチャンネル名:\n{raw.ch_names}")
# Out:
# ファイル存在確認: True
#
# === データ基本情報 ===
# チャンネル数: 129
# サンプリング周波数: 250.0 Hz
# 記録時間: 136.0 秒
#
# チャンネル名:
# ['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9', 'E10', 'E11', 'E12', 'E13', 'E14', 'E15', 'E16', 'E17', 'E18', 'E19', 'E20', 'E21', 'E22', 'E23', 'E24', 'E25', 'E26', 'E27', 'E28', 'E29', 'E30', 'E31', 'E32', 'E33', 'E34', 'E35', 'E36', 'E37', 'E38', 'E39', 'E40', 'E41', 'E42', 'E43', 'E44', 'E45', 'E46', 'E47', 'E48', 'E49', 'E50', 'E51', 'E52', 'E53', 'E54', 'E55', 'E56', 'E57', 'E58', 'E59', 'E60', 'E61', 'E62', 'E63', 'E64', 'E65', 'E66', 'E67', 'E68', 'E69', 'E70', 'E71', 'E72', 'E73', 'E74', 'E75', 'E76', 'E77', 'E78', 'E79', 'E80', 'E81', 'E82', 'E83', 'E84', 'E85', 'E86', 'E87', 'E88', 'E89', 'E90', 'E91', 'E92', 'E93', 'E94', 'E95', 'E96', 'E97', 'E98', 'E99', 'E100', 'E101', 'E102', 'E103', 'E104', 'E105', 'E106', 'E107', 'E108', 'E109', 'E110', 'E111', 'E112', 'E113', 'E114', 'E115', 'E116', 'E117', 'E118', 'E119', 'E120', 'E121', 'E122', 'E123', 'E124', 'E125', 'E126', 'E127', 'E128', 'E129']
# C:\Users\hiro2\AppData\Local\Temp\ipykernel_3580\441777474.py:11: RuntimeWarning: Omitted 106 annotation(s) that were outside data range.
#   raw = mne.io.read_raw_eeglab(set_path, preload=True, verbose=False)
# C:\Users\hiro2\AppData\Local\Temp\ipykernel_3580\441777474.py:11: RuntimeWarning: Limited 2 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_eeglab(set_path, preload=True, verbose=False)
# C:\Users\hiro2\AppData\Local\Temp\ipykernel_3580\441777474.py:11: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(set_path, preload=True, verbose=False)

# %%
import pandas as pd

events_path = os.path.join(data_path, "sub-001", "ses-01", "eeg",
                           "sub-001_ses-01_task-MusicListening_run-1_events.tsv")

events_df = pd.read_csv(events_path, sep='\t')
print("\n=== イベント情報 ===")
print(events_df)
# Out:
# === イベント情報 ===
#            onset  duration       sample  trial_type  response_time  stim_file  \
# 0       0.212676    1000.0      53.1689         NaN            NaN        NaN
# 1       0.434672    1000.0     108.6680         NaN            NaN        NaN
# 2       0.543674    1000.0     135.9184         NaN            NaN        NaN
# 3       0.649678    1000.0     162.4195         NaN            NaN        NaN
# 4       0.756678    1000.0     189.1695         NaN            NaN        NaN
# ..           ...       ...          ...         ...            ...        ...
# 123  1999.875681    1000.0  499968.9203         NaN            NaN        NaN
# 124  2003.027676    1000.0  500756.9189         NaN            NaN        NaN
# 125  2003.036678    1000.0  500759.1694         NaN            NaN        NaN
# 126  2003.045680    1000.0  500761.4200         NaN            NaN        NaN
# 127  2003.048677    1000.0  500762.1693         NaN            NaN        NaN
#
#     value
# 0    SESS
# 1    CELL
# 2    CELL
# 3    CELL
# 4    CELL
# ..    ...
# 123  resp
# 124  resp
# 125  TRSP
# 126  TRSP
# 127  TRSP
#
# [128 rows x 7 columns]
